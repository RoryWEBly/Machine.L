# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt  # Corrected 'pylot' to 'pyplot'
import seaborn as sns

# Corrected magic command: added space between '%' and 'matplotlib'
# %matplotlib inline

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# Define the file path
file_path = r"C:\Users\richm\Downloads\titanic_train.csv"

# Load the dataset into a DataFrame
titanic_data = pd.read_csv(file_path)

# Display the first few rows of the dataset
print(titanic_data.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import pandas as pd

# Load the dataset (make sure to adjust the path if needed)
file_path = r"C:\Users\richm\Downloads\titanic_train.csv"
train = pd.read_csv(file_path)  # This line defines 'train'
# Count missing values in each column
missing_values = train.isnull().sum()
print(missing_values)

# Visualize missing values with a heatmap
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(train.isnull(), yticklabels=False, cbar=True, cmap="viridis")
plt.title('Missing Values Heatmap')
plt.show()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train['Age'].mean()
# Out:
# 29.69911764705882

# %%
train['Fare'].mean()
# Out:
# 32.204207968574636

# %%
#visualisation continuation
sns.set_style('whitegrid')
sns.countplot(x='Survived',data=train,palette='magma')
# Out:
# C:\Users\richm\AppData\Local\Temp\ipykernel_32792\3655616984.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Survived',data=train,palette='magma')
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.set_style("whitegrid")
sns.countplot(x="Survived", hue="Pclass", data=train, palette="rainbow")
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.histplot(train['Age'].dropna(), kde=True, color='darkred', bins=10)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
train['Age'].dropna().hist(bins=10, color='darkred', alpha=0.9)
# Out:
# <Axes: >

# %%
train['SibSp'].mean()
# Out:
# 0.5230078563411896

# %%
sns.countplot(x='SibSp', data=train)
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
train['Fare'].hist(color='green', bins=20, figsize=(8, 4))
# Out:
# <Axes: >

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset (adjust the file path as necessary)
file_path = r"C:\Users\richm\Downloads\titanic_train.csv"
train = pd.read_csv(file_path)  # This defines 'train'

# Check if 'Pclass' and 'Age' columns exist
print(train.columns)

# Create a boxplot if the DataFrame is defined
plt.figure(figsize=(12, 7))  # Set figure size
sns.boxplot(x='Pclass', y='Age', data=train, palette='winter')  # Create boxplot
plt.title('Boxplot of Age by Pclass')  # Add title
plt.show()  # Display the plot
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
# C:\Users\richm\AppData\Local\Temp\ipykernel_32792\3684196269.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Pclass', y='Age', data=train, palette='winter')  # Create boxplot

# %%
sns.heatmap(train.isnull(),yticklabels=False,cbar=True,cmap='viridis')
# Out:
# <Axes: >

# %%
train.drop('Cabin', axis=1, inplace=True)

# %%
train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
sns.heatmap(train.isnull(), yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <Axes: >

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
sex= pd.get_dummies(train['Sex'],drop_first=True)

# %%
sex
# Out:
#       male
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# ..     ...
# 886   True
# 887  False
# 888  False
# 889   True
# 890   True
#
# [891 rows x 1 columns]

# %%
sex.shape
# Out:
# (891, 1)

# %%
train.shape
# Out:
# (891, 11)

# %%
embark = pd.get_dummies(train['Embarked'],drop_first=True)

# %%
embark
# Out:
#          Q      S
# 0    False   True
# 1    False  False
# 2    False   True
# 3    False   True
# 4    False   True
# ..     ...    ...
# 886  False   True
# 887  False   True
# 888  False   True
# 889  False  False
# 890   True  False
#
# [891 rows x 2 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
train.drop(['Sex','Embarked','Name','Ticket'],axis=1,inplace=True)

# %%
train
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
train=pd.concat([train,sex,embark],axis=1)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare   male      Q  \
# 0            1         0       3  22.0      1      0   7.2500   True  False
# 1            2         1       1  38.0      1      0  71.2833  False  False
# 2            3         1       3  26.0      0      0   7.9250  False  False
# 3            4         1       1  35.0      1      0  53.1000  False  False
# 4            5         0       3  35.0      0      0   8.0500   True  False
#
#        S
# 0   True
# 1  False
# 2   True
# 3   True
# 4   True

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test,y_train, y_test = train_test_split(train.drop('Survived',axis=1),
                                          train['Survived'],test_size=0.20,
                                          random_state=101)

# %%
x_train.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 x_train.shape
#
# NameError: name 'x_train' is not defined

# %%
X_test.shape

# %%
y_train.shape

# %%
y_test.shape

# %%
X_train.head()

# %%
x_train.columns

# %%
x_test.shape

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()

# %%
logmodel

# %%
from sklearn.impute import SimpleImputer

# Impute missing values with the mean (or median, mode, etc.)
imputer = SimpleImputer(strategy='mean')  # Options: 'mean', 'median', 'most_frequent'
x_train_imputed = imputer.fit_transform(x_train)

logmodel.fit(x_train_imputed, y_train)

# %%
from sklearn.impute import SimpleImputer

# Impute missing values in x_train (if not already done)
imputer = SimpleImputer(strategy='mean')
x_train_imputed = imputer.fit_transform(x_train)

# Train the model
logmodel.fit(x_train_imputed, y_train)

# Impute missing values in X_test using the same imputer
X_test_imputed = imputer.transform(X_test)

# Make predictions
predictions = logmodel.predict(X_test_imputed)

# %%
predictions

# %%
pip install scikit_plot

# %%
pip install scikit-plot

# %%
pip install scipy==1.11.4

# %%
import scipy
print(scipy.__version__)

# %%
# Function to encode Cabin availability
def encode_cabin(cabin):
    return 0 if pd.isnull(cabin) else 1

# %%
sns.heatmap(train.isnull(), yticklabels = False, cbar = True, cmap = 'viridis')

# %%
train.head(10)

# %%
train['Age'] = train[['Age', 'Pclass']].apply(lambda x: round(impute_age(x, mean_ages), 1), axis =1)

# %%
sns.heatmap(train.isnull(), yticklabels = False, cbar = True, cmap = 'viridis')

# %%
train.head(10)

# %%
sns.heatmap(train.isnull(), yticklabels = False, cbar = True, cmap = 'viridis')

# %%
# Function to encode Cabin availability
def encode_cabin(cabin):
    return 0 if pd.isnull(cabin) else 1

# %%
# Apply the function to the Cabin column
train['Cabin'] = train['Cabin'].apply(encode_cabin)

# %%
train.head(10)

# %%
sns.heatmap(train.isnull(), yticklabels = False, cbar = True, cmap = 'viridis')
# Out:
# <Axes: >

# %%
train.dropna(inplace = True)

# %%
sns.heatmap(train.isnull(), yticklabels = False, cbar = True, cmap = 'viridis')
# Out:
# <Axes: >

# %%
train
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare   male      Q  \
# 0              1         0       3  22.0      1      0   7.2500   True  False
# 1              2         1       1  38.0      1      0  71.2833  False  False
# 2              3         1       3  26.0      0      0   7.9250  False  False
# 3              4         1       1  35.0      1      0  53.1000  False  False
# 4              5         0       3  35.0      0      0   8.0500   True  False
# ..           ...       ...     ...   ...    ...    ...      ...    ...    ...
# 885          886         0       3  39.0      0      5  29.1250  False   True
# 886          887         0       2  27.0      0      0  13.0000   True  False
# 887          888         1       1  19.0      0      0  30.0000  False  False
# 889          890         1       1  26.0      0      0  30.0000   True  False
# 890          891         0       3  32.0      0      0   7.7500   True   True
#
#          S
# 0     True
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 714 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  714 non-null    int64
#  1   Survived     714 non-null    int64
#  2   Pclass       714 non-null    int64
#  3   Age          714 non-null    float64
#  4   SibSp        714 non-null    int64
#  5   Parch        714 non-null    int64
#  6   Fare         714 non-null    float64
#  7   male         714 non-null    bool
#  8   Q            714 non-null    bool
#  9   S            714 non-null    bool
# dtypes: bool(3), float64(2), int64(5)
# memory usage: 46.7 KB
